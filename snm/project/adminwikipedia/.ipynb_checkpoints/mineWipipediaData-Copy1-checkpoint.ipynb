# %% [markdown]
# Dataset source = http://snap.stanford.edu/data/wiki-RfA.html <br>
# Dataset title = "Wikipedia Requests for Adminship (with text)"<br>
# Dataset public = Yes

# %% [markdown]
# #### Stats coming from dataset
# (median/mean: 19/34 tokens)<br>
# Nodes	10,835<br>
# Edges	159,388<br>
# Triangles	956,428<br>
# Type of graph: Directed Signed Network

# %% [markdown]
# #### Dataset format
# *Fields*<br>
# SRC: user name of source, i.e., voter<br>
# TGT: user name of target, i.e., the user running for election<br>
# VOT: the source's vote on the target (-1 = oppose; 0 = neutral; 1 = support)<br>
# RES: the outcome of the election (-1 = target was rejected as admin; 1 = target was accepted)<br>
# YEA: the year in which the election was started<br>
# DAT: the date and time of this vote<br>
# TXT: the comment written by the source, in wiki markup<br>
# <br>
# <br>
# *Example*<br>
# SRC:Guettarda<br>
# TGT:Lord Roem<br>
# VOT:1<br>
# RES:1<br>
# YEA:2013<br>
# DAT:19:53, 25 January 2013<br>
# TXT:'''Support''' per [[WP:DEAL]]: clueful, and unlikely to break Wikipedia.<br>

# %%
import networkx as nx
import  pickle
import pandas as pd
import numpy as np
import glob
import os
import re
from collections import Counter
import pylab as plt

# %% [markdown]
# First let's setup the directed graph instance.

# %%
G = nx.DiGraph()

# %% [markdown]
# Load dataset

# %%
files = glob.glob("./*.txt")
files
# Out:
# ['./wiki-RfAv2.txt']

# %%
listWords = []
for file in files:
    with open(file, mode="r") as f:
        content = f.read().splitlines()

srcNodes = []
count = 1
for text in content:
    count = count + 1
    if count == 10000: 
        break
    textsp = re.split(r":::", text)
    if textsp[0] == 'TGT' or textsp[0] == 'SRC':
        srcNodes.append(textsp[1])

# %%
srcNodes[0:5]
# Out:
# ['Steel1943', 'BDD', 'Cuchullain', 'BDD', 'INeverCry']

# %% [markdown]
# Lets get the number of unique nodes first by usig common

# %%
from collections import Counter
cntr = Counter(srcNodes)
result=cntr.most_common()

# %%
print("Unique nodes version 1 is ", len(result))
# Out:
# Unique nodes version 1 is  505

# %% [markdown]
# Now let's do this via removing duplicates converting to a set

# %%
tst = set(result)
print(len(tst))
# Out:
# 505

# %%
print("Unique nodes version 2 is ",len(tst))
# Out:
# Unique nodes version 2 is  505

# %%
content[0:5]
# Out:
# ['SRC:::Steel1943', 'TGT:::BDD', 'VOT:::1', 'RES:::1', 'YEA:::2013']

# %% [markdown]
# Now let's build the graph

# %%
#Check if all the fields are present
DAT=""
RES=0
SRC=""
TGT=""
TXT=""
VOT=0
YEA=0
count = 1
for text in content:
    count = count + 1
    if count == 10000: 
        break
    count = count +1
    textsp = re.split(r":::", text)
    if textsp[0] == 'DAT':
        DAT=textsp[1]
    if textsp[0] == 'RES':
        RES=textsp[1]
    if textsp[0] == 'SRC':
        SRC=textsp[1]
    if textsp[0] == 'TGT':
        TGT=textsp[1]
    if textsp[0] == 'TXT':
        G.add_edge(SRC, TGT)
        G[SRC][TGT]['VOT'] = VOT
        G[SRC][TGT]['RES'] = RES
        G[SRC][TGT]['YEA'] = YEA
        G[SRC][TGT]['DAT'] = DAT
        G[SRC][TGT]['TXT'] = textsp[1]
        DAT=""
        RES=0
        SRC=""
        TGT=""
        TXT=""
        VOT=0
        YEA=0
    if textsp[0] == 'VOT':
        VOT=textsp[1]
    if textsp[0] == 'YEA':
        YEA=textsp[1]
print(count)
# Out:
# 1586201

# %%
G.number_of_nodes()
# Out:
# 11381

# %%
G.number_of_edges()
# Out:
# 189003

# %%
pickle.dump( G, open( "fullGraph.pickle", "wb" ) )

# %%
G = pickle.load( open( "fullGraph.pickle", "rb" ) )

# %%
nx.write_gexf(G, "fullGraph.gexf")

# %%
G.number_of_nodes()
# Out:
# 11381

# %%
G.number_of_edges()
# Out:
# 189003

# %%
tmplist = list(G.nodes())
print(tmplist[0:5])
# Out:
# ['Steel1943', 'BDD', 'Cuchullain', 'INeverCry', 'Cncmaster']

# %% [markdown]
# Now let's prit an edge

# %%
tmp = list(G.edges.data())
print(tmp[0:1])
# Out:
# [('Steel1943', 'BDD', {'VOT': '1', 'RES': '1', 'YEA': '2013', 'DAT': '23:13, 19 April 2013', 'TXT': "'''Support''' as co-nom."})]

# %% [markdown]
# Now let's print a node

# %%
tmp = list(G.nodes.data())
print(tmp[0:1])
# Out:
# [('Steel1943', {})]

# %%
help(nx.algorithms)
# Out:
# Help on package networkx.algorithms in networkx:
#
# NAME
#     networkx.algorithms
#
# PACKAGE CONTENTS
#     approximation (package)
#     assortativity (package)
#     bipartite (package)
#     boundary
#     bridges
#     centrality (package)
#     chains
#     chordal
#     clique
#     cluster
#     coloring (package)
#     communicability_alg
#     community (package)
#     components (package)
#     connectivity (package)
#     core
#     covering
#     cuts
#     cycles
#     dag
#     distance_measures
#     distance_regular
#     dominance
#     dominating
#     efficiency
#     euler
#     flow (package)
#     graphical
#     hierarchy
#     hybrid
#     isolate
#     isomorphism (package)
#     link_analysis (package)
#     link_prediction
#     lowest_common_ancestors
#     matching
#     minors
#     mis
#     operators (package)
#     reciprocity
#     richclub
#     shortest_paths (package)
#     similarity
#     simple_paths
#     smetric
#     structuralholes
#     swap
#     threshold
#     tournament
#     traversal (package)
#     tree (package)
#     triads
#     vitality
#     voronoi
#     wiener
#
# SUBMODULES
#     all
#     astar
#     attracting
#     beamsearch
#     betweenness
#     betweenness_subset
#     biconnected
#     binary
#     breadth_first_search
#     closeness
#     connected
#     correlation
#     current_flow_betweenness
#     current_flow_betweenness_subset
#     current_flow_closeness
#     degree_alg
#     dense
#     depth_first_search
#     edgedfs
#     eigenvector
#     flow_matrix
#     generic
#     harmonic
#     hits_alg
#     katz
#     load
#     mixing
#     neighbor_degree
#     pagerank_alg
#     pairs
#     product
#     reaching
#     semiconnected
#     strongly_connected
#     subgraph_alg
#     unary
#     unweighted
#     weakly_connected
#     weighted
#
# FILE
#     /anaconda3/envs/fastai-cpu/lib/python3.6/site-packages/networkx/algorithms/__init__.py

# %%
def plot_degree_distribution(tG): 
    degs = {}
    for n in tG.nodes():
        deg = tG.degree(n) 
        if deg not in degs:
            degs[deg] = 0
        degs[deg] += 1
    items = sorted(degs.items())
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.plot([k for (k,v) in items], [v for (k,v) in items]) 
    ax.set_xscale('log') 
    ax.set_yscale('log')
    plt.title("Wikipedia Degree Distribution") 
    fig.savefig("degree_distribution.png")

# %%
plot_degree_distribution(G)

# %%
items = sorted(degs.items())
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot([k for (k,v) in items], [v for (k,
v) in items]) ax.set_xscale(’log’) ax.set_yscale(’log’)
plt.title("Wikipedia Degree Distribution") fig.savefig("degree_distribution.png")

# %% [markdown]
# To iterate

# %%
count = 1
for node in G.nodes():
    count = count+1
    if count == 10: break
    print(node, G.degree(node))
# Out:
# Steel1943 4
# BDD 142
# Cuchullain 65
# INeverCry 133
# Cncmaster 21
# Miniapolis 158
# Sven Manguard 129
# Ramaksoud2000 6

# %%
nx.draw(g)
#nx.draw_random(G)
#nx.draw_circular(G)
#nx.draw_spectral(G)

# %%
#nx.draw_random(G)
